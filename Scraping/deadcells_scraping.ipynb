# %% [markdown]
# # Imports

# %%
from urllib.request import urlopen
from bs4 import BeautifulSoup
import re
import urllib.request
from PIL import Image

# %% [markdown]
# # Found urls of each monsters from website

# %%
# open the url
html = urlopen('https://deadcells.gamepedia.com/Enemies')
bs = BeautifulSoup(html, 'html.parser')
# find all img elements where .png in their 'src'
images = bs.find_all('img', {'src':re.compile('.png')})

# print the url of each image scrapped
for image in images: 
    print(image['src']+'\n')

# check number of images
print(f'I found {len(images)} monsters in DeadCells Website')
# Out:
# https://static.wikia.nocookie.net/deadcells_gamepedia_en/images/c/c3/Zombie.png/revision/latest/scale-to-width-down/24?cb=20190402183113
#
# https://static.wikia.nocookie.net/deadcells_gamepedia_en/images/e/e3/Undead_Archer.png/revision/latest/scale-to-width-down/52?cb=20190402184236
#
# https://static.wikia.nocookie.net/deadcells_gamepedia_en/images/3/37/Shieldbearer.png/revision/latest/scale-to-width-down/36?cb=20190402184336
#
# https://static.wikia.nocookie.net/deadcells_gamepedia_en/images/6/69/Grenadier.png/revision/latest/scale-to-width-down/49?cb=20190402184311
#
# https://static.wikia.nocookie.net/deadcells_gamepedia_en/images/3/3f/Bombardier.png/revision/latest/scale-to-width-down/53?cb=20190402201348
#
# https://static.wikia.nocookie.net/deadcells_gamepedia_en/images/a/ad/Bat.png/revision/latest/scale-to-width-down/38?cb=20190402184402
#
# https://static.wikia.nocookie.net/deadcells_gamepedia_en/images/1/19/Kamikaze.png/revision/latest/scale-to-width-down/28?cb=20190402184856
#
# https://static.wikia.nocookie.net/deadcells_gamepedia_en/images/1/14/Runner.png/revision/latest/scale-to-width-down/100?cb=20190402184455
#
# https://static.wikia.nocookie.net/deadcells_gamepedia_en/images/c/c8/Inquisitor.png/revision/latest/scale-to-width-down/46?cb=20190402185847
#
# https://static.wikia.nocookie.net/deadcells_gamepedia_en/images/c/cc/Protector.png/revision/latest/scale-to-width-down/51?cb=20190402184518
#
# https://static.wikia.nocookie.net/deadcells_gamepedia_en/images/8/81/Hammer.png/revision/latest/scale-to-width-down/98?cb=20190402190456
#
# https://static.wikia.nocookie.net/deadcells_gamepedia_en/images/2/23/Sweeper.png/revision/latest/scale-to-width-down/63?cb=20190724185703
#
# https://static.wikia.nocookie.net/deadcells_gamepedia_en/images/3/39/Buzzcutter.png/revision/latest/scale-to-width-down/49?cb=20190402185822
#
# https://static.wikia.nocookie.net/deadcells_gamepedia_en/images/3/3f/Corpse_Fly.png/revision/latest/scale-to-width-down/38?cb=20190402185405
#
# https://static.wikia.nocookie.net/deadcells_gamepedia_en/images/8/86/Sewer_Fly.png/revision/latest/scale-to-width-down/45?cb=20190404221723
#
# https://static.wikia.nocookie.net/deadcells_gamepedia_en/images/2/25/Purulent_Zombie_%28Sewers%29.png/revision/latest/scale-to-width-down/35?cb=20200707144138
#
# https://static.wikia.nocookie.net/deadcells_gamepedia_en/images/4/41/Purulent_Zombie_%28Graveyard%29.png/revision/latest/scale-to-width-down/41?cb=20190402190000
#
# https://static.wikia.nocookie.net/deadcells_gamepedia_en/images/c/cf/Disgusting_Worm.png/revision/latest/scale-to-width-down/66?cb=20190402190219
#
# https://static.wikia.nocookie.net/deadcells_gamepedia_en/images/b/bc/Corpse_Worm.png/revision/latest/scale-to-width-down/31?cb=20190402185937
#
# https://static.wikia.nocookie.net/deadcells_gamepedia_en/images/d/d4/Weaver_Worm.png/revision/latest/scale-to-width-down/31?cb=20190402201235
#
# https://static.wikia.nocookie.net/deadcells_gamepedia_en/images/a/ab/Scorpion.png/revision/latest/scale-to-width-down/73?cb=20190402190147
#
# https://static.wikia.nocookie.net/deadcells_gamepedia_en/images/8/83/Impaler_%28Enemy%29.png/revision/latest/scale-to-width-down/67?cb=20190402190241
#
# https://static.wikia.nocookie.net/deadcells_gamepedia_en/images/d/d1/Sewer%27s_Tentacle.png/revision/latest/scale-to-width-down/59?cb=20190816100407
#
# https://static.wikia.nocookie.net/deadcells_gamepedia_en/images/4/43/Catcher.png/revision/latest/scale-to-width-down/127?cb=20190402185002
#
# https://static.wikia.nocookie.net/deadcells_gamepedia_en/images/0/0a/Cleaver_%28Enemy%29.png/revision/latest/scale-to-width-down/104?cb=20190402184918
#
# https://static.wikia.nocookie.net/deadcells_gamepedia_en/images/3/37/Pirate_Captain.png/revision/latest/scale-to-width-down/62?cb=20190402184832
#
# https://static.wikia.nocookie.net/deadcells_gamepedia_en/images
#
# https://static.wikia.nocookie.net/deadcells_gamepedia_en/images/8/89/Oven_Knight.png/revision/latest/scale-to-width-down/104?cb=20200509174917
#
# https://static.wikia.nocookie.net/deadcells_gamepedia_en/images/b/bb/Toxic_Miasma.png/revision/latest/scale-to-width-down/125?cb=20200509174956
#
# https://static.wikia.nocookie.net/deadcells_gamepedia_en/images/7/72/Weirded_Warrior.png/revision/latest/scale-to-width-down/80?cb=20200509175038
#
# https://static.wikia.nocookie.net/deadcells_gamepedia_en/images/d/dc/Corpulent_Zombie.png/revision/latest/scale-to-width-down/115?cb=20200509175123
#
# https://static.wikia.nocookie.net/deadcells_gamepedia_en/images/4/41/Dancer.png/revision/latest/scale-to-width-down/55?cb=20200509175203
#
# https://static.wikia.nocookie.net/deadcells_gamepedia_en/images/f/fb/Infected_Worker.png/revision/latest/scale-to-width-down/85?cb=20200809012543
#
# https://static.wikia.nocookie.net/deadcells_gamepedia_en/images/a/a6/Living_Barrel.png/revision/latest/scale-to-width-down/59?cb=20200809012822
#
# https://static.wikia.nocookie.net/deadcells_gamepedia_en/images/a/aa/Demolisher.png/revision/latest/scale-to-width-down/90?cb=20201221173743
#
# https://static.wikia.nocookie.net/deadcells_gamepedia_en/images/d/d1/Yeeter.png/revision/latest/scale-to-width-down/60?cb=20200214165329
#
# https://static.wikia.nocookie.net/deadcells_gamepedia_en/images/9/9f/Jerkshroom.png/revision/latest/scale-to-width-down/26?cb=20200214165534
#
# https://static.wikia.nocookie.net/deadcells_gamepedia_en/images/1/11/Banished.png/revision/latest/scale-to-width-down/105?cb=20200214164739
#
# https://static.wikia.nocookie.net/deadcells_gamepedia_en/images/4/4e/Blowgunner.png/revision/latest/scale-to-width-down/62?cb=20200214164755
#
# https://static.wikia.nocookie.net/deadcells_gamepedia_en/images/1/1c/Giant_Tick.png/revision/latest/scale-to-width-down/145?cb=20200214164814
#
# https://static.wikia.nocookie.net/deadcells_gamepedia_en/images/3/32/Myopic_Crow.png/revision/latest/scale-to-width-down/45?cb=20210126204456
#
# https://static.wikia.nocookie.net/deadcells_gamepedia_en/images/2/21/Stone_Warden.png/revision/latest/scale-to-width-down/156?cb=20210126204525
#
# https://static.wikia.nocookie.net/deadcells_gamepedia_en/images/2/25/Cold_Blooded_Guardian.png/revision/latest/scale-to-width-down/103?cb=20210126204608
#
# https://static.wikia.nocookie.net/deadcells_gamepedia_en/images/4/42/Apostate.png/revision/latest/scale-to-width-down/96?cb=20210126204629
#
# https://static.wikia.nocookie.net/deadcells_gamepedia_en/images/e/e4/Failed_Homunculus.png/revision/latest/scale-to-width-down/29?cb=20210126204702
#
# https://static.wikia.nocookie.net/deadcells_gamepedia_en/images/9/99/Clumsy_Swordsman.png/revision/latest/scale-to-width-down/52?cb=20210126204727
#
# https://static.wikia.nocookie.net/deadcells_gamepedia_en/images/d/d5/Dastardly_Archer.png/revision/latest/scale-to-width-down/69?cb=20210126204752
#
# https://static.wikia.nocookie.net/deadcells_gamepedia_en/images/6/62/Compulsive_Gravedigger.png/revision/latest/scale-to-width-down/72?cb=20210126204817
#
# https://static.wikia.nocookie.net/deadcells_gamepedia_en/images/9/93/Running_Zombie.png/revision/latest/scale-to-width-down/28?cb=20170805103240
#
# https://static.wikia.nocookie.net/deadcells_gamepedia_en/images/3/3a/Elite_Lieutenant.png/revision/latest/scale-to-width-down/27?cb=20190402185754
#
# //i.creativecommons.org/l/by-nc-sa/3.0/88x31.png
#
# /resources-ucp/resources/assets/poweredby_mediawiki_88x31.png
#
# I found 84 monsters in DeadCells Website

# %% [markdown]
# # Download the images based on their urls

# %%
# function to download images based on their url
def download_png(url,file_path,file_name):
    full_path= file_path+file_name+'.png'
    # download the image from the url to the full_path
    urllib.request.urlretrieve(url,full_path)

# %%
i=0
for img in images:
    try:
        download_png(img['src'],'images/',f'deadcells_{i}')
        i+=1
    except:
        pass

# %% [markdown]
# # Checking images downloaded

# %%
# Opening one of the images
im = Image.open("images poke_style/deadcells_2.png")    
# show image 
im.show() 
# check the size
print(im.size)
